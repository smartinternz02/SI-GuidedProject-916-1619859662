# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(r"D:\geethanjaliexternship\source files\insurance.csv")

# %%
dataset.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dataset.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
dataset["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
x = dataset.iloc[:,0:6].values
y = dataset.iloc[:,6].values

# %%
x.shape
# Out:
# (1338, 6)

# %%
y.shape
# Out:
# (1338,)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

ct = ColumnTransformer([("oh",OneHotEncoder(),[1,4,5])],remainder = "passthrough")
x = ct.fit_transform(x)

# %%
x.shape
# Out:
# (1338, 11)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 0)

# %%
x_train.shape
# Out:
# (1070, 11)

# %%
x_test.shape
# Out:
# (268, 11)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
cat = Sequential()

# %%
cat.add(Dense(5,kernel_initializer = "random_uniform",activation = "relu"))

# %%
cat.add(Dense(10,kernel_initializer = "random_uniform",activation = "relu"))

# %%
cat.add(Dense(1,kernel_initializer = "random_uniform",activation = "relu"))

# %%
cat.compile("adam","mean_squared_error",metrics=["mse"])

# %%
cat.fit(x_train,y_train,batch_size=32,epochs=1000)
# Out:
# Epoch 1/1000
# 34/34 [==============================] - 1s 2ms/step - loss: 309971342.1714 - mse: 309971342.1714
# Epoch 2/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 309180138.0571 - mse: 309180138.0571
# Epoch 3/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 306093277.7143 - mse: 306093277.7143
# Epoch 4/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 319797884.3429 - mse: 319797884.3429
# Epoch 5/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 349976458.9714 - mse: 349976458.9714
# Epoch 6/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 320240369.3714 - mse: 320240369.3714
# Epoch 7/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 306646119.3143 - mse: 306646119.3143
# Epoch 8/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 337930440.2286 - mse: 337930440.2286
# Epoch 9/1000
# ...

# %%
ypred  = cat.predict(x_test)

# %%
ypred
# Out:
# array([[ 9842.903 ],
#        [ 8843.489 ],
#        [43861.37  ],
#        [17308.14  ],
#        [ 4657.683 ],
#        [ 2504.5505],
#        [ 4342.7856],
#        [15207.467 ],
#        [ 8410.502 ],
#        [ 7829.3076],
#        [ 6594.6597],
#        [ 9513.553 ],
#        [10009.298 ],
#        [ 4577.3384],
#        [26466.672 ],
#        [10284.243 ],
#        [ 9542.612 ],
#        [ 6449.626 ],
#        [ 7679.115 ],
#        [24610.39  ],
#        [33365.906 ],
#        [14993.358 ],
#        [10957.075 ],
#        [31980.855 ],
#        [ 4732.053 ],
#        [ 9625.89  ],
#        [ 3094.4084],
#        [ 9350.867 ],
#        [ 4627.719 ],
#        [ 9351.268 ],
#        [ 8266.037 ],
#        [47017.785 ],
#        [16092.182 ],
#        [14265.791 ],
#        [18196.11  ],
#        [ 6066.9053],
#        [11843.331 ],
#        [32499.688 ],
#        [34809.703 ],
#        [ 6594.951 ],
#        [ 4641.941 ],
#        [ 3228.4453],
#        [28301.164 ],
# ...

# %%
y_test
# Out:
# array([ 9724.53    ,  8547.6913  , 45702.02235 , 12950.0712  ,
#         9644.2525  ,  4500.33925 ,  2198.18985 , 11436.73815 ,
#         7537.1639  ,  5425.02335 ,  6753.038   , 10493.9458  ,
#         7337.748   ,  4185.0979  , 18310.742   , 10702.6424  ,
#        12523.6048  ,  3490.5491  ,  6457.8434  , 33475.81715 ,
#        23967.38305 , 12643.3778  , 23045.56616 , 23065.4207  ,
#         1674.6323  ,  4667.60765 ,  3732.6251  ,  7682.67    ,
#         3756.6216  ,  8413.46305 ,  8059.6791  , 48970.2476  ,
#        12979.358   , 20630.28351 , 14571.8908  ,  4137.5227  ,
#         8347.1643  , 51194.55914 , 40003.33225 ,  1880.487   ,
#         5458.04645 ,  2867.1196  , 20149.3229  , 47496.49445 ,
#        36149.4835  , 26018.95052 , 19749.38338 ,  6940.90985 ,
#         4718.20355 , 22192.43711 ,  2899.48935 , 18838.70366 ,
#        23568.272   , 46255.1125  , 24227.33724 ,  3268.84665 ,
#         2322.6218  ,  8827.2099  , 14478.33015 , 13112.6048  ,
# ...

# %%
yp=cat.predict(sc.transform(ct.transform([[19,"female",27.900,0,"yes","southwest"]])))

# %%
yp
# Out:
# array([[22070.957]], dtype=float32)
